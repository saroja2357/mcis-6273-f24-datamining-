# %%
curl -H "token:peUoGReGomLyRqAedzPNFbpUtrtznRun" “https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:80249&units=standard&startdate=2008-12-15&enddate=2009-01-21&limit=1000"
# Out:
#   Cell In[1], line 1
#     curl -H "token:peUoGReGomLyRqAedzPNFbpUtrtznRun" “https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&locationid=ZIP:80249&units=standard&startdate=2008-12-15&enddate=2009-01-21&limit=1000"
#             ^
# SyntaxError: invalid syntax

# %%
import requests

# %%
token = "peUoGReGomLyRqAedzPNFbpUtrtznRun"  # not a real access key obviously

# %%
url = "https://www.ncdc.noaa.gov/cdo-web/api/v2/data"

# %%
response = requests.get(url, headers={'token': token})

# %%
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/conda/envs/sau24s/lib/python3.8/site-packages/requests/models.py:960, in Response.json(self, **kwargs)
#     959 try:
# --> 960     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     961 except UnicodeDecodeError:
#     962     # Wrong UTF codec detected; usually because it's not UTF-8
#     963     # but some other 8-bit codec.  This is an RFC violation,
#     964     # and the server didn't bother to tell us what codec *was*
#     965     # used.
#
# File /opt/conda/envs/sau24s/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
# ...

# %%
def new_func(response):
# Out:
#   Cell In[7], line 1
#     def new_func(response):
#                            ^
# SyntaxError: unexpected EOF while parsing

# %%
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/conda/envs/sau24s/lib/python3.8/site-packages/requests/models.py:960, in Response.json(self, **kwargs)
#     959 try:
# --> 960     return complexjson.loads(self.content.decode(encoding), **kwargs)
#     961 except UnicodeDecodeError:
#     962     # Wrong UTF codec detected; usually because it's not UTF-8
#     963     # but some other 8-bit codec.  This is an RFC violation,
#     964     # and the server didn't bother to tell us what codec *was*
#     965     # used.
#
# File /opt/conda/envs/sau24s/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
# ...

# %%
import requests
import json
import os

# Function to fetch weather data from NOAA API
def fetch_weather_data(start_date, end_date):
    url = "https://www.ncei.noaa.gov/data"
    params = {
        "datasetid": "GHCND",
        "locationid": "ZIP:80249",
        "startdate": start_date,
        "enddate": end_date,
        "units": "standard",
        "limit": 1000
    }
    headers = {"token": "peUoGReGomLyRqAedzPNFbpUtrtznRun"}  # Replace 'your_noaa_api_key' with your actual NOAA API key
    response = requests.get(url, params=params, headers=headers)
    data = response.json()
    return data

# Define date ranges
date_ranges = [
    ("2008-12-15", "2009-01-21"),
    ("2009-12-15", "2010-01-21"),
    ("2010-12-15", "2011-01-21"),
    ("2011-12-15", "2012-01-21"),
    ("2012-12-15", "2013-01-21"),
    ("2013-12-15", "2014-01-21"),
    ("2014-12-15", "2015-01-21"),
    ("2015-12-15", "2016-01-21"),
    ("2016-12-15", "2017-01-21"),
    ("2017-12-15", "2018-01-21"),
    ("2018-12-15", "2019-01-21"),
    ("2019-12-15", "2020-01-21"),
    ("2020-12-15", "2021-01-21"),
    ("2021-12-15", "2022-01-21")
]

# Fetch data for each date range and save to JSON file
for i, (start_date, end_date) in enumerate(date_ranges, start=2008):
    data = fetch_weather_data(start_date, end_date)
    file_name = f"data/winter_{i}-{i+1}.json"
    with open(file_name, "w") as f:
        json.dump(data, f)
    print(f"Data saved for {file_name}")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/conda/envs/sau24s/lib/python3.8/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/conda/envs/sau24s/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#
# ...

# %%
import requests
import json
import os

# Function to fetch weather data from NOAA API
def fetch_weather_data(start_date, end_date):
    url = "https://www.ncei.noaa.gov/data"
    params = {
        "datasetid": "GHCND",
        "locationid": "ZIP:80249",
        "startdate": start_date,
        "enddate": end_date,
        "units": "standard",
        "limit": 1000
    }
    headers = {"token": "peUoGReGomLyRqAedzPNFbpUtrtznRun"}  # Replace 'your_noaa_api_key' with your actual NOAA API key
    response = requests.get(url, params=params, headers=headers)
    print(response.text) 
    data = response.json()
    return data

# Define date ranges
date_ranges = [
    ("2008-12-15", "2009-01-21"),
    ("2009-12-15", "2010-01-21"),
    ("2010-12-15", "2011-01-21"),
    ("2011-12-15", "2012-01-21"),
    ("2012-12-15", "2013-01-21"),
    ("2013-12-15", "2014-01-21"),
    ("2014-12-15", "2015-01-21"),
    ("2015-12-15", "2016-01-21"),
    ("2016-12-15", "2017-01-21"),
    ("2017-12-15", "2018-01-21"),
    ("2018-12-15", "2019-01-21"),
    ("2019-12-15", "2020-01-21"),
    ("2020-12-15", "2021-01-21"),
    ("2021-12-15", "2022-01-21")
]

# Fetch data for each date range and save to JSON file
for i, (start_date, end_date) in enumerate(date_ranges, start=2008):
    data = fetch_weather_data(start_date, end_date)
    file_name = f"data/winter_{i}-{i+1}.json"
    with open(file_name, "w") as f:
        json.dump(data, f)
    print(f"Data saved for {file_name}")
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# <html>
#  <head>
#   <title>Index of /data</title>
#  </head>
#  <body>
# <h1>Index of /data</h1>
#   <table>
#    <tr><th><a href="?C=N;O=D">Name</a></th><th><a href="?C=M;O=A">Last modified</a></th><th><a href="?C=S;O=A">Size</a></th><th><a href="?C=D;O=A">Description</a></th></tr>
#    <tr><th colspan="4"><hr></th></tr>
# <tr><td><a href="/">Parent Directory</a></td><td>&nbsp;</td><td align="right">  - </td><td>&nbsp;</td></tr>
# <tr><td><a href="aerosols-esrl-gmd/">aerosols-esrl-gmd/</a></td><td align="right">2018-07-25 10:54  </td><td align="right">  - </td><td>&nbsp;</td></tr>
# <tr><td><a href="african-easterly-wave-climatology/">african-easterly-wave-climatology/</a></td><td align="right">2021-03-05 16:41  </td><td align="right">  - </td><td>&nbsp;</td></tr>
# ...
